# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso, BayesianRidge
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score, max_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings("ignore")


csv_filenames = [
    "Center_13_Rank1.csv", "Center_43_Rank2.csv", "Center_10_Rank3.csv", "Center_52_Rank4.csv", "Center_137_Rank5.csv",
    "Center_67_Rank6.csv", "Center_11_Rank7.csv", "Center_174_Rank8.csv", "Center_104_Rank9.csv", "Center_27_Rank10.csv"
]

for i in csv_filenames:
    data = pd.read_csv("{}".format(i))
    train_data = data[data['week'] <= 130]
    test_data = data[data['week'] > 130]

    X_train = train_data[["checkout_price","cuisine","meal_id","emailer_for_promotion","homepage_featured", "category", "week"]]
    y_train = train_data["num_orders"]
    X_test = test_data[["checkout_price","cuisine","meal_id","emailer_for_promotion","homepage_featured", "category", "week"]]
    y_test = test_data["num_orders"]

    categorical_cols = ["cuisine","meal_id", "category"]


    categorical_transformer = Pipeline(steps=[
        ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
    ])


    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', categorical_transformer, categorical_cols)
        ], remainder='passthrough')

    regressors = [
      ("Linear Regression", LinearRegression()),
      ("Ridge Regression", Ridge(alpha=1.0)),
      ("Lasso Regression", Lasso(alpha=1.0)),
      ("Bayesian Ridge", BayesianRidge()),
      ("Random forest regressor", RandomForestRegressor(n_estimators=100, random_state=42)),
      ("XGBRegressor", XGBRegressor()),
      ("Gradient Boosting Regressor", GradientBoostingRegressor(random_state=42))
  ]

    print(f"\n\n{i}\n\n")
    for name, model in regressors:
        pipeline = Pipeline(steps=[('preprocessor', preprocessor), (name, model)])
        pipeline.fit(X_train, y_train)

        y_pred = pipeline.predict(X_test)

        mse = mean_squared_error(y_test, y_pred)
        rmse=np.sqrt(mse)
        mae = mean_absolute_error(y_test, y_pred)
        r_squared = r2_score(y_test, y_pred)


        print(f"{name}: RMSE = {round(rmse, 4)}, MAE = {round(mae, 4)}, R-squared = {round(r_squared, 4)}")
# Out:
# Center_13_Rank1.csv
#
#
# Linear Regression: RMSE = 466.3427, MAE = 194.7813, R-squared = 0.6556
# Ridge Regression: RMSE = 466.2894, MAE = 194.6423, R-squared = 0.6557
# Lasso Regression: RMSE = 465.7142, MAE = 197.2413, R-squared = 0.6565
# Bayesian Ridge: RMSE = 466.2917, MAE = 194.654, R-squared = 0.6557
# Random forest regressor: RMSE = 358.9881, MAE = 148.6287, R-squared = 0.7959
# XGBRegressor: RMSE = 354.9545, MAE = 141.2704, R-squared = 0.8005
# Gradient Boosting Regressor: RMSE = 394.9661, MAE = 175.9509, R-squared = 0.753
#
#
# Center_43_Rank2.csv
#
#
# Linear Regression: RMSE = 555.5776, MAE = 235.7589, R-squared = 0.5209
# Ridge Regression: RMSE = 555.5585, MAE = 235.6145, R-squared = 0.5209
# Lasso Regression: RMSE = 555.4744, MAE = 237.6939, R-squared = 0.5211
# Bayesian Ridge: RMSE = 555.5154, MAE = 235.4455, R-squared = 0.521
# Random forest regressor: RMSE = 399.8088, MAE = 142.8584, R-squared = 0.7519
# XGBRegressor: RMSE = 404.759, MAE = 142.1709, R-squared = 0.7457
# Gradient Boosting Regressor: RMSE = 417.4638, MAE = 169.5046, R-squared = 0.7295
#
#
# Center_10_Rank3.csv
#
#
# Linear Regression: RMSE = 230.1973, MAE = 143.8637, R-squared = 0.7908
# Ridge Regression: RMSE = 230.1711, MAE = 143.6534, R-squared = 0.7908
# Lasso Regression: RMSE = 228.2033, MAE = 142.1754, R-squared = 0.7944
# Bayesian Ridge: RMSE = 230.1644, MAE = 143.5736, R-squared = 0.7909
# Random forest regressor: RMSE = 172.7841, MAE = 113.8285, R-squared = 0.8821
# XGBRegressor: RMSE = 204.7953, MAE = 119.5383, R-squared = 0.8344
# Gradient Boosting Regressor: RMSE = 208.1952, MAE = 137.1535, R-squared = 0.8289
#
#
# Center_52_Rank4.csv
#
#
# Linear Regression: RMSE = 228.2479, MAE = 143.6141, R-squared = 0.7866
# Ridge Regression: RMSE = 227.6427, MAE = 142.765, R-squared = 0.7877
# Lasso Regression: RMSE = 231.4913, MAE = 150.394, R-squared = 0.7805
# Bayesian Ridge: RMSE = 227.7476, MAE = 142.8911, R-squared = 0.7875
# Random forest regressor: RMSE = 157.7862, MAE = 101.162, R-squared = 0.898
# XGBRegressor: RMSE = 178.7513, MAE = 106.3577, R-squared = 0.8691
# Gradient Boosting Regressor: RMSE = 181.2767, MAE = 124.7922, R-squared = 0.8654
#
#
# Center_137_Rank5.csv
#
#
# Linear Regression: RMSE = 137.6587, MAE = 95.1664, R-squared = 0.7011
# Ridge Regression: RMSE = 137.6359, MAE = 95.1321, R-squared = 0.7012
# Lasso Regression: RMSE = 146.2614, MAE = 104.3434, R-squared = 0.6626
# Bayesian Ridge: RMSE = 137.6309, MAE = 95.1227, R-squared = 0.7013
# Random forest regressor: RMSE = 133.4669, MAE = 84.691, R-squared = 0.7191
# XGBRegressor: RMSE = 139.559, MAE = 89.7085, R-squared = 0.6928
# Gradient Boosting Regressor: RMSE = 143.0497, MAE = 102.2748, R-squared = 0.6773
#
#
# Center_67_Rank6.csv
#
#
# Linear Regression: RMSE = 417.9911, MAE = 144.5119, R-squared = 0.5346
# Ridge Regression: RMSE = 417.5272, MAE = 144.618, R-squared = 0.5356
# Lasso Regression: RMSE = 417.5316, MAE = 147.275, R-squared = 0.5356
# Bayesian Ridge: RMSE = 417.5596, MAE = 144.6387, R-squared = 0.5355
# Random forest regressor: RMSE = 306.2738, MAE = 106.3926, R-squared = 0.7501
# XGBRegressor: RMSE = 305.399, MAE = 108.6748, R-squared = 0.7515
# Gradient Boosting Regressor: RMSE = 326.6207, MAE = 127.7031, R-squared = 0.7158
#
#
# Center_11_Rank7.csv
#
#
# Linear Regression: RMSE = 282.3305, MAE = 155.8664, R-squared = 0.611
# Ridge Regression: RMSE = 282.1683, MAE = 155.6471, R-squared = 0.6115
# Lasso Regression: RMSE = 279.318, MAE = 155.5309, R-squared = 0.6193
# Bayesian Ridge: RMSE = 282.0201, MAE = 155.4481, R-squared = 0.6119
# Random forest regressor: RMSE = 207.0983, MAE = 95.8596, R-squared = 0.7907
# XGBRegressor: RMSE = 184.4935, MAE = 92.6831, R-squared = 0.8339
# Gradient Boosting Regressor: RMSE = 207.0452, MAE = 108.4128, R-squared = 0.7908
#
#
# Center_174_Rank8.csv
#
#
# Linear Regression: RMSE = 265.8307, MAE = 138.5771, R-squared = 0.7011
# Ridge Regression: RMSE = 265.3298, MAE = 138.2665, R-squared = 0.7022
# Lasso Regression: RMSE = 260.5913, MAE = 136.0177, R-squared = 0.7128
# Bayesian Ridge: RMSE = 265.3332, MAE = 138.2685, R-squared = 0.7022
# Random forest regressor: RMSE = 160.2294, MAE = 87.7851, R-squared = 0.8914
# XGBRegressor: RMSE = 177.5076, MAE = 92.3332, R-squared = 0.8667
# Gradient Boosting Regressor: RMSE = 186.876, MAE = 105.7601, R-squared = 0.8523
#
#
# Center_104_Rank9.csv
#
#
# Linear Regression: RMSE = 155.4919, MAE = 103.5692, R-squared = 0.6829
# Ridge Regression: RMSE = 155.5068, MAE = 103.4156, R-squared = 0.6828
# Lasso Regression: RMSE = 159.8782, MAE = 104.9835, R-squared = 0.6648
# Bayesian Ridge: RMSE = 155.524, MAE = 103.2864, R-squared = 0.6828
# Random forest regressor: RMSE = 149.0063, MAE = 87.9758, R-squared = 0.7088
# XGBRegressor: RMSE = 156.3162, MAE = 89.7957, R-squared = 0.6795
# Gradient Boosting Regressor: RMSE = 149.8019, MAE = 96.2795, R-squared = 0.7057
#
#
# Center_27_Rank10.csv
#
#
# Linear Regression: RMSE = 200.0511, MAE = 117.3308, R-squared = 0.7556
# Ridge Regression: RMSE = 197.8665, MAE = 114.4089, R-squared = 0.7609
# Lasso Regression: RMSE = 196.1728, MAE = 115.2755, R-squared = 0.765
# Bayesian Ridge: RMSE = 197.8465, MAE = 114.3927, R-squared = 0.761
# Random forest regressor: RMSE = 133.8424, MAE = 78.4044, R-squared = 0.8906
# XGBRegressor: RMSE = 151.9987, MAE = 84.7541, R-squared = 0.8589
# Gradient Boosting Regressor: RMSE = 152.6768, MAE = 90.5061, R-squared = 0.8577
